# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# ## Add your code below following the instructions given in the course

# %% [markdown]
# ## Exercise 2 - Create a markdown cell with the title of the notebook. (1 pt)

# %% [markdown]
# #### Tools for Data Sciecne Week 4 Assignment

# %% [markdown]
# ## Exercise 3 - Create a markdown cell for an introduction. (1 pt)

# %% [markdown]
# This file is for module Tools for Data Science Week 4 assgnment for IBM Data Science Professional Certificate, written by author Li Shuman. Thank you for your time in marking this assignment and I will appreciate if you leave your valuable comments.

# %% [markdown]
# ## Exercise 4 - Create a markdown cell to list data science languages. (3 pts)

# %% [markdown]
# <ol>
#     <li>SQL</li>
#     <li>R</li>
#     <li>PYTHON</li>
#     <li>Go</li>
#     <li>Julia</li>
#     <li>PHP</li>
# </ol>

# %% [markdown]
# ## Exercise 5 - Create a markdown cell to list data science libraries. (3 pts)

# %% [markdown]
# <ol>
#     <li>TensorFlow</li>
#     <li>Scitkit-learn</li>
#     <li>Pytorch</li>
#     <li>Theano</li>
#     <li>Numpy</li>
#     <li>Scipy</li>
#     <li>Matplotlib</li>
#     <li>Keras</li>
#     <li>Pandas</li>
# </ol>

# %% [markdown]
# ## Exercise 6 - Create a markdown cell with a table of Data Science tools. (3 pts)

# %% [markdown]
# <table>
#   <tr>
#     <th>Data Science Tools</th>
#   </tr>
#     <tr>
#     <td>IBM SPSS</td>
#     </tr>
#     <tr>
#     <td>Matplotlib</td>
#     </tr>
#     <tr>
#     <td>Julia</td>
#     </tr>
#     <tr>
#     <td>Jupyter Notebook</td>
#     </tr>
#
# </table>

# %% [markdown]
# ## Exercise 7 - Create a markdown cell introducing arithmetic expression examples. (1 pt)

# %% [markdown]
# <table>
#   <tr>
#     <th>Arithmetic Expression</th>
#       <th>Examples</th>
# </tr>
#     <tr>
#         <td><center>+</center></td>
#       <td>2+3=5</td>
#     </tr>
#     <tr>
#     <td><center>/</center></td>
#         <td>6/3=2</td>
#     </tr>
#     <tr>
#     <td><center>*</center></td>
#         <td>2*3=6</td>
#     </tr>
# </table>

# %% [markdown]
# ## Exercise 8 - Create a code cell to multiply and add numbers.(2 pts)

# %%
def multiplyNumber(a,b):
    return a*b
def addNumber(a,b):
    return a+b

# %%
multiplyNumber(2,3)
# Out:
# 6

# %%
addNumber(2,3)
# Out:
# 5

# %% [markdown]
# ## Exercise 9 - Create a code cell to convert minutes to hours. (2 pts)

# %%
def convertMin(a):
    return a/60+(a%60/60/100)

# %%
convertMin(70)
# Out:
# 1.1683333333333334

# %% [markdown]
# ## Exercise 10 -Insert a markdown cell to list Objectives. (3 pts)

# %% [markdown]
# <ol>
#     <li>Be a man</li>
#     <li>Be a good man</li>
# </ol>

# %% [markdown]
# ## Exercise 11 - Create a markdown cell to indicate the Author’s name. (2 pts)

# %% [markdown]
# #### Li Shuman

# %% [markdown]
# ## Exercise 12 - Share your notebook through GitHub (3 pts)

# %%
This shared.

# %% [markdown]
# ## Exercise 13 - Take a screenshot of the first page of the notebook. (1 pt)

# %% [markdown]
# ![Screenshot%202023-02-28%20at%2012.28.50.png](attachment:Screenshot%202023-02-28%20at%2012.28.50.png)
